# %% [markdown]
# Download model:

# %%
hf download coqui/XTTS-v2 --local-dir ./translation_service/models/coqui_XTTS-v2!hf download

# %% [markdown]
# to run the model:

# %%
uvicorn app:app --port 8002  --reload
