# %% [markdown]
# Download model:

# %%
hf download facebook/nllb-200-distilled-600M --local-dir ./translation_service/models/facebook-nllb-200

# %% [markdown]
# to run the model:

# %%
uvicorn app:app --port 8001  --reload
